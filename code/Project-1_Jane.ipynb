# %% [markdown]
# # Project 1: SAT & ACT Analysis
#
#
# #### by Jane Liang  on  Nov. 11 2018

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Nearly every four-year college and university require high school students to take the **SAT** or **ACT** as part of the college admissions process for testing students' knowledge and aptitude on an equal playing field. The **SAT** and **ACT** are quite similar in many ways (intensive reading, cover algebra I&II, geometry, trigonometry, and an optional writing section) and have been about equally popular for several years. However, the SAT, once the nation’s dominant college admission exam, fell behind the ACT in recent years after its rival locked up testing contracts with more than a dozen states, including many in the Southern and Central regions of the country.The ACT had been the overall leader since 2012.
#
# In this EDA (Exploration Data Analysis), I will be analyzing **SAT** and **ACT** scores by state, as well as participation rates in the year of 2017 and 2018 for answering following specific questions:
#
# -  What is the more commonly taken test in each state?
# -  Which state has the highest or lowest rate of participation on SAT and ACT tests? Possible reasons?
# -  Which state has the highest or lowest SAT/ACT scores? Possible reasons?
# -  Is there any patterns in the data? Any possible relations between subsets of the data? (i.e., scores vs participation rate)
# -  What is the major differences between 2017 and 2018?
# -  What are some other interesting fact in the data?
#
# According to the exploration of the data, we can make recommendation to College Board, which owns SAT in order to increase SAT participation.
#
# Data source: <br>
# [2017 SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/) <br>
# [2017 ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)<br>
# [2018 SAT](https://reports.collegeboard.org/sat-suite-program-results/state-results)<br>
# [2018 ACT](http://www.act.org/content/dam/act/unsecured/documents/cccr2018/Average-Scores-by-State.pdf) <br>

# %% [markdown]
# ## Executive Summary
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
from IPython.display import display

print ('SAT 2017:')
display(sat_2017.head(10))
print ('ACT 2017:')
display(act_2017.head(10))
# Out:
# SAT 2017:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# The **sat_2017** and **act_2017** datasets are providing participation rates and average scores by state across the United States. In **sat_2017** data set, the columns are comprised of average scores of two SAT sections (each scored between 0-800) and total SAT score which is  for the class of 2017. In **act_2017** data set, the columns are consist of average scores of four individual ACT sections(English, Math, Reading, Science: all range from 1 to 36) and composite ACT which is the average scores of these four sections. The **act_2017** dataset included national scores as well resulted in 52 rows compared with the **sat_2017** dataset. In addition, scores of **SAT** test are represented in _integer_ numbers whereas **ACT** scores are in _float number_ with one decimal point.

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %% [markdown]
# Answer: Data has no missing values.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
sat_2017.describe().T
# Out:
#                                     count         mean        std    min  \
# Evidence-Based Reading and Writing   51.0   569.117647  45.666901  482.0
# Math                                 51.0   547.627451  84.909119   52.0
# Total                                51.0  1126.098039  92.494812  950.0
#
#                                        25%     50%     75%     max
# Evidence-Based Reading and Writing   533.5   559.0   613.0   644.0
# Math                                 522.0   548.0   599.0   651.0
# Total                               1055.5  1107.0  1212.0  1295.0

# %%
act_2017.describe().T
# Out:
#          count       mean       std   min     25%    50%     75%   max
# English   52.0  20.919231  2.332132  16.3  19.000  20.55  23.300  25.5
# Math      52.0  21.173077  1.963602  18.0  19.400  20.90  23.100  25.3
# Reading   52.0  22.001923  2.048672  18.1  20.475  21.70  24.125  26.0
# Science   52.0  21.040385  3.151113   2.3  19.900  21.15  22.525  24.9

# %% [markdown]
# Answer: According to the summary of statistics for both datasets, the minimum scores in Math section of **sat_2017** and Science section of **act_2017** look abnormal compare with the original dataset. The states contain the minimum scores of **SAT** 'Math' and **ACT** 'Science' are shown in below.

# %%
sat_2017[sat_2017['Math'] == sat_2017['Math'].min()]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
act_2017[act_2017['Science'] == act_2017['Science'].min()]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %% [markdown]
# Apparently, there are errors exist in the record of Maryland. The **SAT** 'Math' score of Maryland should be 524 instead of 52, the **ACT** 'Science' score of Maryland should be 23.2 instead of 2.3.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code
sat_2017.loc[20,'Math']=524
act_2017.loc[21,'Science']=23.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
print("sat_2017 features'data type:")
print('--------')
print(sat_2017.dtypes)
print('')
print('')
print("act_2017 features'data type:")
print('--------')
print('')
print(act_2017.dtypes)
# Out:
# sat_2017 features'data type:
# --------
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
#
# act_2017 features'data type:
# --------
#
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: The data type of 'Composite' column in act_2017 dataset is object which should be float64. It would be better to convert Participation rate to 'int' or 'float' for processing data.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
sat_2017['Participation'] = sat_2017['Participation'].map(lambda x: int(x.strip('%')))
act_2017['Participation'] = act_2017['Participation'].map(lambda x: int(x.strip('%')))

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
act_2017.loc[51,'Composite'] = 20.2

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
act_2017['Composite'] = act_2017['Composite'].map(lambda x: float(x))

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
print("sat_2017 features'data type:")
print('--------')
print(sat_2017.dtypes)
print('')
print('')
print("act_2017 features'data type:")
print('--------')
print('')
print(act_2017.dtypes)
# Out:
# sat_2017 features'data type:
# --------
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
#
# act_2017 features'data type:
# --------
#
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
sat_2017_column_names = ['state','sat_2017_par','sat_2017_ebrw','sat_2017_math','sat_2017_total']
act_2017_column_names = ['state','act_2017_par','act_2017_eng','act_2017_math',
                    'act_2017_reading','act_2017_science','act_2017_composite']
sat_2017.columns = sat_2017_column_names
act_2017.columns = act_2017_column_names

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|*object*|sat_2017|The state of the country|
# |sat_2017_par|*float*|sat_2017|The participation rate of SAT test for the class of 2017(%)|
# |sat_2017_ebrw|*integer*|sat_2017|The average scores of the SAT Evidence-Based Reading and Writing test in each state for the class of 2017|
# |sat_2017_math|*integer*|sat_2017|The average scores of the SAT Math test in each state for the class of 2017|
# |sat_2017_total|*integer*|sat_2017|The total average scores of the SAT test in each state for the class of 2017|
# |state|*object*|act_2017|The state of the country|
# |act_2017_par|*float*|act_2017|The participation rate of ACT test for the class of 2017(%)|
# |act_2017_eng|*float*|act_2017|The average scores of the ACT English test in each state for the class of 2017|
# |act_2017_math|*float*|act_2017|The average scores of the ACT Math test in each state for the class of 2017|
# |act_2017_reading|*float*|act_2017|The average scores of the ACT reading test in each state for the class of 2017|
# |act_2017_science|*float*|act_2017|The average scores of the ACT science test in each state for the class of 2017|
# |act_2017_composite|*float*|act_2017|The average of four ACT test scores in each state for the class of 2017|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %% [markdown]
# The act_2017 has 52 rows whereas the sat_2017 has 51 rows since act_2017 include National scores.

# %%
#code
act_2017.drop(0, inplace=True)

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
combined_2017 = pd.merge(act_2017, sat_2017, on='state')

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
combined_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#Import datasets
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')

# %%
# print first 5 rows 
from IPython.display import display

print ('SAT 2018:')
display(sat_2018.head(5))
print ('ACT 2018:')
display(act_2018.head(5))
# Out:
# SAT 2018:
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
#
#       Unnamed: 5     Unnamed: 6
# 0           1166            NaN
# 1            NaN   angry octopi
# 2  little lapdog            NaN
# 3            NaN            NaN
# 4  rabid kittens  fierce ferret
# ACT 2018:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
 # Drop the last two columns in sat_2018 dataset 
sat_2018.drop(columns = ['Unnamed: 5','Unnamed: 6'],inplace=True)

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
# State            52 non-null object
# Participation    52 non-null object
# Composite        52 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# Answer: There's no missing values in sat_2017 and sat_2018.

# %%
# Rename columns 
sat_2018_column_names = ['state','sat_2018_par','sat_2018_ebrw','sat_2018_math','sat_2018_total']
act_2018_column_names = ['state','act_2018_par','act_2018_composite']
sat_2018.columns = sat_2018_column_names
act_2018.columns = act_2018_column_names

# %%
# Drop the extra row in the act_2018
act_2018.drop(51,inplace=True)

# %% [markdown]
# It seems there are some differences in the 'state' column in the act_2018 compared with sat_2018, I wanted to identify them and set the names in an identical way so that I can merge them without conflicts.

# %%
#Check if the state names are idendical
act_2018[act_2018['state']!=sat_2018['state']]['state']
# Out:
# 8     Washington, D.C.
# 24         Mississippi
# 36            Oklahoma
# Name: state, dtype: object

# %%
# Check the state name for combined file
combined_2017.loc[(8,24,36),'state']
# Out:
# 8     District of Columbia
# 24             Mississippi
# 36                Oklahoma
# Name: state, dtype: object

# %%
# change the state names to consistant with combined file
act_2018.loc[(8,24,36),'state'] =['District of Columbia','Mississippi','Oklahoma']
sat_2018.loc[(8,24,36),'state'] =['District of Columbia','Mississippi','Oklahoma']

# %%
# change the percentage object to float numbers
sat_2018['sat_2018_par'] = sat_2018['sat_2018_par'].map(lambda x: int(x.strip('%')))
act_2018['act_2018_par'] = act_2018['act_2018_par'].map(lambda x: int(x.strip('%')))

# %%
#combine sat_2018 and act_2018
combined_2018 = pd.merge(act_2018, sat_2018, on='state')

# %%
#save the combined 2018 sat and act record as combined_2018.csv
combined_2018.to_csv('../data/combined_2018.csv')

# %% [markdown]
# ## The data dictionary of sat_2018 and act_2018
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|*object*|sat_2018|The state of the country|
# |sat_2018_par|*float*|sat_2018|The participation rate of SAT test for the class of 2018(%)|
# |sat_2018_ebrw|*integer*|sat_2018|The average scores of the SAT Evidence-Based Reading and Writing test in each state for the class of 2018|
# |sat_2018_math|*integer*|sat_2018|The average scores of the SAT Math test in each state for the class of 2018|
# |sat_2018_total|*integer*|sat_2018|The total average scores of the SAT test in each state for the class of 2018|
# |state|*object*|act_2018|The state of the country|
# |act_2018_par|*float*|act_2018|The participation rate of ACT test for the class of 2018(%)|
# |act_2018_composite|*float*|act_2018|The average of four ACT test scores in each state for the class of 2018|

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#combine the dataframes
final = pd.merge(combined_2017, combined_2018, on='state')

# %%
#Set the state as the index
final = final.set_index('state')

# %%
#save the merged datafram as final.csv
final.to_csv('../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe().T
# Out:
#                     count         mean        std    min      25%     50%  \
# act_2017_par         51.0    65.254902  32.140842    8.0    31.00    69.0
# act_2017_eng         51.0    20.931373   2.353677   16.3    19.00    20.7
# act_2017_math        51.0    21.182353   1.981989   18.0    19.40    20.9
# act_2017_reading     51.0    22.013725   2.067271   18.1    20.45    21.8
# act_2017_science     51.0    21.450980   1.739353   18.2    19.95    21.3
# act_2017_composite   51.0    21.519608   2.020695   17.8    19.80    21.4
# sat_2017_par         51.0    39.803922  35.276632    2.0     4.00    38.0
# sat_2017_ebrw        51.0   569.117647  45.666901  482.0   533.50   559.0
# sat_2017_math        51.0   556.882353  47.121395  468.0   523.50   548.0
# sat_2017_total       51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# act_2018_par         51.0    61.627451  34.078122    7.0    28.50    66.0
# act_2018_composite   51.0    21.498039   2.117686   17.7    19.95    21.3
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def std(data):
    sum_num = []
    for i in range(len(data)):
        sum_num_i = (data[i]-(sum(data)/len(data)))**2
        sum_num.append(sum_num_i)   
    std = (sum(sum_num)/(len(data)))**(1/2)
    return std

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd = {key: std(value) for key,value in final.items() if final[key].dtype != 'object'}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
import numpy as np
np.std(final.iloc[:,1:])
# Out:
# act_2017_eng           2.330488
# act_2017_math          1.962462
# act_2017_reading       2.046903
# act_2017_science       1.722216
# act_2017_composite     2.000786
# sat_2017_par          34.929071
# sat_2017_ebrw         45.216970
# sat_2017_math         46.657134
# sat_2017_total        91.583511
# act_2018_par          33.742369
# act_2018_composite     2.096822
# sat_2018_par          36.946619
# sat_2018_ebrw         47.034610
# sat_2018_math         47.301946
# sat_2018_total        93.227424
# dtype: float64

# %% [markdown]
# Answer: No, the manually calculated standard deviation doesn't match up with the output form pandas describe but match up with numpy's std method. Pandas calculate the standard deviation as follows:
#
# $$\sigma = \sqrt{\frac{1}{n-1}\sum_{i=1}^n(x_i - \mu)^2}$$

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#sort the dataframe based on 2017 sat scores
final.sort_values('sat_2017_par',ascending=False)['sat_2017_par'].head()
# Out:
# state
# District of Columbia    100
# Michigan                100
# Connecticut             100
# Delaware                100
# New Hampshire            96
# Name: sat_2017_par, dtype: int64

# %%
final.sort_values('sat_2017_par',ascending=False)['sat_2017_par'].tail()
# Out:
# state
# Arkansas        3
# Wyoming         3
# North Dakota    2
# Mississippi     2
# Iowa            2
# Name: sat_2017_par, dtype: int64

# %% [markdown]
# Sort data by 2017 SAT participation rate, the highest and lowest participation rate are 100% and 2%, respectively. The states where have highest and lowest participation rates for 2017 SAT are printed below.

# %%
#write the mask condition for the highest 2017 SAT participation rate
mask_high_sat2017 = final['sat_2017_par']==final['sat_2017_par'].max()
#show the states where have highest 2017 SAT prticipation rate
High_par_sat_2017 = final[mask_high_sat2017 ].index.values

#write the mask condition for the lowest 2017 SAT participation rate
mask_low_sat2017 = final['sat_2017_par']==final['sat_2017_par'].min()
#show the states where have lowest 2017 SAT prticipation rate
Low_par_sat_2017 = final[mask_low_sat2017 ].index.values

# %%
print('There are {} states have 100% participation rate for the 2017 SAT, they are:{}.'.format(len(High_par_sat_2017),High_par_sat_2017))
print('There are {} states have 2% participation rate for the 2017 SAT, they are:{}.'.format(len(Low_par_sat_2017),Low_par_sat_2017))
# Out:
# There are 4 states have 100% participation rate for the 2017 SAT, they are:['Connecticut' 'Delaware' 'District of Columbia' 'Michigan'].
# There are 3 states have 2% participation rate for the 2017 SAT, they are:['Iowa' 'Mississippi' 'North Dakota'].

# %%
#sort the dataframe based on 2018 sat scores
final.sort_values('sat_2018_par',ascending=False)['sat_2018_par'].head()
# Out:
# state
# Colorado       100
# Connecticut    100
# Delaware       100
# Michigan       100
# Idaho          100
# Name: sat_2018_par, dtype: int64

# %%
#sort the dataframe based on 2018 sat scores
final.sort_values('sat_2018_par',ascending=False)['sat_2018_par'].tail()
# Out:
# state
# Mississippi     3
# Iowa            3
# Wisconsin       3
# Wyoming         3
# North Dakota    2
# Name: sat_2018_par, dtype: int64

# %% [markdown]
# Sort data by 2018 SAT participation rate, the highest and lowest participation rate are still 100% and 2%, respectively.However, states where have highest and lowest participation rates for 2018 SAT are slightly different than 2017 record.

# %%
#write the mask condition for the highest 2018 SAT participation rate
mask_high_sat2018 = final['sat_2018_par']==final['sat_2018_par'].max()
#States where have highest 2018 SAT prticipation rate
High_par_sat_2018 = final[mask_high_sat2018 ].index.values

#write the mask condition for the lowest 2018 SAT participation rate
mask_low_sat2018 = final['sat_2018_par']==final['sat_2018_par'].min()
#States where have highest 2018 SAT prticipation rate
Low_par_sat_2018 = final[mask_low_sat2018 ].index.values

# %%
print('There are {} states have 100% participation rate for the 2018 SAT, they are:{}.'.format(len(High_par_sat_2018),High_par_sat_2018))
print('There are {} states have 2% participation rate for the 2018 SAT, they are:{}.'.format(len(Low_par_sat_2018),Low_par_sat_2018))
# Out:
# There are 5 states have 100% participation rate for the 2018 SAT, they are:['Colorado' 'Connecticut' 'Delaware' 'Idaho' 'Michigan'].
# There are 1 states have 2% participation rate for the 2018 SAT, they are:['North Dakota'].

# %%
#sort the dataframe based on 2017 act scores
final.sort_values('act_2017_par',ascending=False)['act_2017_par'].head()
# Out:
# state
# Alabama      100
# Kentucky     100
# Wisconsin    100
# Utah         100
# Tennessee    100
# Name: act_2017_par, dtype: int64

# %%
#sort the dataframe based on 2017 act scores
final.sort_values('act_2017_par',ascending=False)['act_2017_par'].tail()
# Out:
# state
# Pennsylvania     23
# Rhode Island     21
# Delaware         18
# New Hampshire    18
# Maine             8
# Name: act_2017_par, dtype: int64

# %%
#write the mask condition for the highest 2017 ACT participation rate
mask_high_act2017 = final['act_2017_par']==final['act_2017_par'].max()
#States where have highest 2017 ACT prticipation rate
High_par_act_2017 = final[mask_high_act2017].index.values

#write the mask condition for the lowest 2017 ACT participation rate
mask_low_act2017 = final['act_2017_par']==final['act_2017_par'].min()
#States where have highest 2017 ACT prticipation rate
Low_par_act_2017 = final[mask_low_act2017].index.values

# %%
print('There are {} states have 100% participation rate for the 2017 ACT, they are:{}.'.format(len(High_par_act_2017),High_par_act_2017))
print('There are {} states have 2% participation rate for the 2017 ACT, they are:{}.'.format(len(Low_par_act_2017),Low_par_act_2017))
# Out:
# There are 17 states have 100% participation rate for the 2017 ACT, they are:['Alabama' 'Arkansas' 'Colorado' 'Kentucky' 'Louisiana' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nevada' 'North Carolina' 'Oklahoma'
#  'South Carolina' 'Tennessee' 'Utah' 'Wisconsin' 'Wyoming'].
# There are 1 states have 2% participation rate for the 2017 ACT, they are:['Maine'].

# %%
#sort the dataframe based on 2018 sat scores
final.sort_values('act_2018_par',ascending=False)['act_2018_par'].head()
# Out:
# state
# Alabama      100
# Kentucky     100
# Wisconsin    100
# Utah         100
# Tennessee    100
# Name: act_2018_par, dtype: int64

# %%
final.sort_values('act_2018_par',ascending=False)['act_2018_par'].tail()
# Out:
# state
# Pennsylvania     20
# Delaware         17
# New Hampshire    16
# Rhode Island     15
# Maine             7
# Name: act_2018_par, dtype: int64

# %% [markdown]
# There are more than 5 states have 100% participation rates for 2018 ACT test. The lowest participation rate is 7%.

# %%
#write the mask condition for the highest 2018 ACT participation rate
mask_high_act2018 = final['act_2018_par']==final['act_2018_par'].max()
#States where have highest 2018 ACT prticipation rate
High_par_act_2018 = final[mask_high_act2018].index.values

#write the mask condition for the lowest 2018 ACT participation rate
mask_low_act2018 = final['act_2018_par']==final['act_2018_par'].min()
#States where have highest 2017 SAT prticipation rate
Low_par_act_2018 = final[mask_low_act2018].index.values

# %%
print('There are {} states have 100% participation rate for the 2018 ACT, they are:{}.'.format(len(High_par_act_2018),High_par_act_2018))
print('There are {} states have 2% participation rate for the 2018 ACT, they are:{}.'.format(len(Low_par_act_2018),Low_par_act_2018))
# Out:
# There are 17 states have 100% participation rate for the 2018 ACT, they are:['Alabama' 'Arkansas' 'Kentucky' 'Louisiana' 'Mississippi' 'Missouri'
#  'Montana' 'Nebraska' 'Nevada' 'North Carolina' 'Ohio' 'Oklahoma'
#  'South Carolina' 'Tennessee' 'Utah' 'Wisconsin' 'Wyoming'].
# There are 1 states have 2% participation rate for the 2018 ACT, they are:['Maine'].

# %%
final.sort_values('sat_2017_total',ascending=False)['sat_2017_total'].head()
# Out:
# state
# Minnesota    1295
# Wisconsin    1291
# Iowa         1275
# Missouri     1271
# Kansas       1260
# Name: sat_2017_total, dtype: int64

# %%
final.sort_values('sat_2018_total',ascending=False)['sat_2018_total'].head()
# Out:
# state
# Minnesota       1298
# Wisconsin       1294
# North Dakota    1283
# Iowa            1265
# Kansas          1265
# Name: sat_2018_total, dtype: int64

# %% [markdown]
# The state of Minnesota's SAT total average score is the highest in 2017 and 2018.

# %%
final.sort_values('sat_2017_total',ascending=False)['sat_2017_total'].tail()
# Out:
# state
# Maine                   1012
# Idaho                   1005
# Michigan                1005
# Delaware                 996
# District of Columbia     950
# Name: sat_2017_total, dtype: int64

# %%
final.sort_values('sat_2018_total',ascending=False)['sat_2018_total'].tail()
# Out:
# state
# Hawaii                  1010
# Idaho                   1001
# West Virginia            999
# Delaware                 998
# District of Columbia     977
# Name: sat_2018_total, dtype: int64

# %%
final.sort_values('act_2017_composite',ascending=False)['act_2017_composite'].head()
# Out:
# state
# New Hampshire           25.5
# Massachusetts           25.4
# Connecticut             25.2
# Maine                   24.3
# District of Columbia    24.2
# Name: act_2017_composite, dtype: float64

# %%
final.sort_values('act_2018_composite',ascending=False)['act_2018_composite'].head()
# Out:
# state
# Connecticut      25.6
# Massachusetts    25.5
# New Hampshire    25.1
# New York         24.5
# Michigan         24.4
# Name: act_2018_composite, dtype: float64

# %% [markdown]
# The state of New Hampshire has the Highest average composite score for ACT in 2017. However, the state of Connecticut has the Highest average composite score for ACT in 2018.

# %%
final.sort_values('act_2017_composite',ascending=False)['act_2017_composite'].tail()
# Out:
# state
# North Carolina    19.1
# Hawaii            19.0
# South Carolina    18.7
# Mississippi       18.6
# Nevada            17.8
# Name: act_2017_composite, dtype: float64

# %%
final.sort_values('act_2018_composite',ascending=False)['act_2018_composite'].tail()
# Out:
# state
# Alabama           19.1
# Hawaii            18.9
# Mississippi       18.6
# South Carolina    18.3
# Nevada            17.7
# Name: act_2018_composite, dtype: float64

# %% [markdown]
# The state of Nevada has the lowest average composite score for ACT in both 2017 and 2018.

# %%
final.loc[(High_par_sat_2017), ['sat_2017_par','sat_2018_par']]
# Out:
#                       sat_2017_par  sat_2018_par
# state
# Connecticut                    100           100
# Delaware                       100           100
# District of Columbia           100            92
# Michigan                       100           100

# %%
final.loc[High_par_sat_2018, ['sat_2017_par','sat_2018_par']]
# Out:
#              sat_2017_par  sat_2018_par
# state
# Colorado               11           100
# Connecticut           100           100
# Delaware              100           100
# Idaho                  93           100
# Michigan              100           100

# %% [markdown]
# The District of Columbia's participation rate were dropped to 92% in 2018. The state of Colorado's SAT participation rate was 11% in the year of 2017, but the rate was increased to 100% in 2018. The state of Idaho's SAT participation rate also increased from 93% (2017) to 100%(2018).

# %%
final.loc[High_par_act_2017, ['act_2017_par','act_2018_par']]
# Out:
#                 act_2017_par  act_2018_par
# state
# Alabama                  100           100
# Arkansas                 100           100
# Colorado                 100            30
# Kentucky                 100           100
# Louisiana                100           100
# Minnesota                100            99
# Mississippi              100           100
# Missouri                 100           100
# Montana                  100           100
# Nevada                   100           100
# North Carolina           100           100
# Oklahoma                 100           100
# South Carolina           100           100
# Tennessee                100           100
# Utah                     100           100
# Wisconsin                100           100
# Wyoming                  100           100

# %%
final.loc[High_par_act_2018, ['act_2017_par','act_2018_par']]
# Out:
#                 act_2017_par  act_2018_par
# state
# Alabama                  100           100
# Arkansas                 100           100
# Kentucky                 100           100
# Louisiana                100           100
# Mississippi              100           100
# Missouri                 100           100
# Montana                  100           100
# Nebraska                  84           100
# Nevada                   100           100
# North Carolina           100           100
# Ohio                      75           100
# Oklahoma                 100           100
# South Carolina           100           100
# Tennessee                100           100
# Utah                     100           100
# Wisconsin                100           100
# Wyoming                  100           100

# %% [markdown]
# The State of Colorado's ACT test participation rate were dropped from 100% in 2017 to 30% in 2018. The State of Minnesota's participation rate shows a little bit decrease from the year of 2017 to 2018. The states of Nebraska and Ohio's participation rate are increased from 84% and 75% (2017) to 100% in the year of 2018.

# %%
final[(final['sat_2017_par']>50) & (final['act_2017_par']>50)].index.values
# Out:
# array(['Florida', 'Georgia', 'Hawaii'], dtype=object)

# %%
final[(final['sat_2018_par']>50) & (final['act_2018_par']>50)].index.values
# Out:
# array(['Florida', 'Georgia', 'Hawaii', 'North Carolina', 'South Carolina'],
#       dtype=object)

# %% [markdown]
# The participation rate of the states of Florida, Georgia, and Hawaii are greater than 50% on both tests in the year of 2017 and 2018. The state of North Carolina and South Carolina shows that the participation rate on both tests are greater than 50% in the year of 2018.

# %% [markdown]
# In this point, it should be noted that the District of Columbia and the states of Colorado and Illinois show the interesting trend from the record of 2017 and 2018.

# %%
final.loc[['District of Columbia','Colorado','Illinois','Florida']][['act_2017_par',
                                                'act_2018_par','sat_2017_par','sat_2018_par','sat_2017_total',
                                                'sat_2018_total','act_2017_composite','act_2018_composite']]
# Out:
#                       act_2017_par  act_2018_par  sat_2017_par  sat_2018_par  \
# state
# District of Columbia            32            32           100            92
# Colorado                       100            30            11           100
# Illinois                        93            43             9            99
# Florida                         73            66            83            56
#
#                       sat_2017_total  sat_2018_total  act_2017_composite  \
# state
# District of Columbia             950             977                24.2
# Colorado                        1201            1025                20.8
# Illinois                        1115            1019                21.4
# Florida                         1017            1099                19.8
#
#                       act_2018_composite
# state
# District of Columbia                23.6
# Colorado                            23.9
# Illinois                            23.9
# ...

# %% [markdown]
# The District of Columbia's ACT test participation test is relatively low but the average composite test score ranked in top 5. There is a huge change in participation rate for ACT and SAT test from 2107 to 2018 for state of Colorado and Illinois.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
fig = plt.figure(figsize=(18,15))
mask = np.triu(np.ones_like(final.corr()))
col_order = final.corr().sort_values('act_2018_par', ascending=False).index
ax = sns.heatmap(final[col_order].corr(), 
                 annot=True, 
                 annot_kws={'size':15}, 
                 mask=mask,
                 cmap='Blues')
ax.set_title('Correlation of participation rates and test scores of SAT and ACT in 2017 anf 2018', fontsize=20)
ax.tick_params(axis='x', labelsize=15, labelrotation=90)
ax.tick_params(axis='y', labelsize=15, labelrotation=0)
y_min, y_max = ax.get_ylim()
x_min, x_max = ax.get_xlim()
ax.set_ylim(top=y_max+1)
ax.set_xlim(right=x_max-1);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough row
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15,5*nrows)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    if len(list_of_columns) %2 !=0:
        ax[len(list_of_columns)].set_visible(False)
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column],bins=15,color="#3F5D7D") # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(f' Count of States by\n {list_of_titles[i]}', fontsize =18)
        ax[i].set_ylabel('Count of States',fontsize=15)
        ax[i].set_xlabel(list_of_titles[i],fontsize=15);
        ax[i].spines["top"].set_visible(False)  
        ax[i].spines["right"].set_visible(False)  
    plt.tight_layout()

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
subplot_histograms(final,['sat_2017_par','sat_2018_par','act_2017_par','act_2018_par'],
                  ['the participation rate for 2017 SAT','the participation rate for 2018 SAT',
                  'the participation rate for 2017 ACT','the participation rate for 2018 ACT'])

# %% [markdown]
# In the histogram above, the participation rates peaks at between 0 and 10% for SAT test whereas the participation rates peaks at between 90 to 100%. This indicated that more states have attended ACT test in the year of 2017 and 2018. There is a wide spread in the histogram, ranging from below 10 to 100% for both ACT and SAT test records.

# %%
subplot_histograms(final,['sat_2017_math','sat_2018_math','act_2017_math'],
                  ['the average Math score for 2017 SAT','the average Math score for 2018 SAT',
                  'the average Math score for 2017 ACT'])

# %% [markdown]
# There are at least 8 states have scored between 525 to 550 in 2017 and 2018 SAT math test. The spread of 2017 ACT histogram was narrow range form 18 to 25. The distributions maths scores for SAT and ACT don't show symmetrical shape which might be not normal distribution.

# %%
subplot_histograms(final,['sat_2017_ebrw','sat_2018_ebrw','act_2017_reading','act_2017_eng'],
                  ['the average Evidence-based reading \n and writing score for 2017 SAT',
                   'the average Evidence-based reading  \n and writing score for 2018 SAT',
                   'the average Reading score for 2017 ACT','the average English score for 2017 ACT'])

# %% [markdown]
# The shape of histogram of average Reading/Verbal score for SAT and ACT tests are not symmetrical.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def subplot_scatter(dataframe, x, y):
    nrows = int(np.ceil(len(x)/2)) # Makes sure you have enough row
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15,5*nrows)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    if len(x) %2 !=0:
        ax[len(x)].set_visible(False)
    for i in range(len(x)): # Gives us an index value to get into all our lists
        sns.scatterplot(dataframe[x[i]],dataframe[y[i]],ax = ax[i],color="#3F5D7D") # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(x[i] +' vs ' + y[i], fontsize =18)
        ax[i].set_ylabel(y[i],fontsize=15)
        ax[i].set_xlabel(x[i],fontsize=15);
        ax[i].spines["top"].set_visible(False)  
        ax[i].spines["right"].set_visible(False)  
    plt.tight_layout()

# %%
subplot_scatter(final,['sat_2017_math','sat_2017_ebrw','sat_2017_total','sat_2017_total','act_2017_composite'],
                ['act_2017_math','act_2017_reading','act_2017_composite','sat_2018_total','act_2018_composite'])

# %% [markdown]
# The data don't seem to resemble any kind of pattern between ACT and SAT test scores, then no relationship exists between ACT and SAT test. As expected, there's a clear positive linear relationship between 2017 test scores and 2018 test scores. As the composite and total scores for 2017 ACT and SAT test increases, the composite and total scores for 2018 ACT and SAT test tend to increase.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# define a function to normalize the values where they can lie in the range (0,1).
final_normed = pd.DataFrame([(final[x]-final[x].min())/
                             (final[x].max()-final[x].min()) for x in final if final[x].dtypes != object]).T

# %%
plt.figure(figsize =(11,15))
sns.boxplot(data=final_normed, 
            width=0.5,
           color="#3F5D7D",
           orient='h');
plt.title('Boxplot of normalized participation rate and scores \n for ACT and SAT tests in the year of 2017 and 2018',fontsize=20);

# %% [markdown]
# We can observe that the distribution of Participation rate on ACT tests are in higher range compare to the Participation rate on SAT test. However, the median value of Participation rate has decreased a little bit in 2018 for the ACT test whereas median value of Participation rate has increased in 2018 compare to 2017. Due to the increasing number of test takers in SAT test, the overall average total scores of SAT has decreased in 2018 compared to 2017 whereas ACT composite scores remain relatively constant.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
sat_diff = final['sat_2018_par']-final['sat_2017_par']
sat_up = sat_diff[sat_diff > 10].sort_values()
sat_down = abs(sat_diff[sat_diff<0].sort_values(ascending=False))

fig,ax = plt.subplots(ncols=2, nrows =1)
sat_up.plot(kind = 'barh', figsize =(25,10),fontsize=25, width = 0.7, color ="#3F5D7D", ax = ax[0]);
ax[0].set_xlabel('% increase',fontsize =28)
ax[0].set_ylabel('State',fontsize =28)
ax[0].set_title('Increase of participation rate for 2018 SAT ',fontsize =28)


sat_down.plot(kind = 'barh', figsize =(25,10),fontsize=25, width = 0.5, color ="#8B0000", ax = ax[1]);
ax[1].set_xlabel('% decrease',fontsize =28)
ax[1].set_ylabel('State',fontsize =28)
ax[1].set_title('Decrease of participation rate for 2018 SAT ',fontsize =28)

plt.tight_layout()
fig.subplots_adjust(wspace=0.5)

# %% [markdown]
# Compared with the year of 2017, more students have participated SAT tests. The state of Illinois and Colorado's participation rates increase 80%. However, there are four states show the decrease of participation rate for 2018 SAT, especially the state of Florida shows 25% decrease in participation rate.

# %%
act_diff = final['act_2018_par']-final['act_2017_par']
act_up = act_diff[act_diff >0].sort_values()
act_down = abs(act_diff[act_diff<-5].sort_values(ascending=False))

fig,ax = plt.subplots(ncols=2, nrows =1)
act_up.plot(kind = 'barh', figsize =(25,10),fontsize=25, width = 0.7, color ="#3F5D7D", ax = ax[0]);
ax[0].set_xlabel('% increase',fontsize =28)
ax[0].set_ylabel('State',fontsize =28)
ax[0].set_title('Increase of participation rate for 2018 ACT ',fontsize =28)

act_down.plot(kind = 'barh', figsize =(25,10),fontsize=25, width = 0.5, color ="#8B0000", ax = ax[1]);
ax[1].set_xlabel('% decrease',fontsize =28)
ax[1].set_ylabel('State',fontsize =28)
ax[1].set_title('Decrease of participation rate for 2018 ACT ',fontsize =28)

plt.tight_layout()
fig.subplots_adjust(wspace=0.5)

# %% [markdown]
# Compared with the year of 2017, less students have participated ACT test. The state of Illinois and Colorado's participation rates decreased 60-80%. There are six states show the incrase of participation rate for 2018 ACT, especially the state of Ohio shows 25% increase on participation rate.

# %%
def subplot_regplot(dataframe, x, y):
    nrows = int(np.ceil(len(x)/2)) # Makes sure you have enough row
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15,5*nrows)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    if len(x) %2 !=0:
        ax[len(x)].set_visible(False)
    for i in range(len(x)): # Gives us an index value to get into all our lists
        sns.regplot(dataframe[x[i]],dataframe[y[i]],ax = ax[i],color="#3F5D7D") # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(x[i] +' vs ' + y[i], fontsize =18)
        ax[i].set_ylabel(y[i],fontsize=15)
        ax[i].set_xlabel(x[i],fontsize=15);
        ax[i].spines["top"].set_visible(False)  
        ax[i].spines["right"].set_visible(False)  
    plt.tight_layout()

# %%
subplot_regplot(final, ['sat_2017_par','sat_2018_par','act_2017_par','act_2018_par'],
                ['sat_2017_total','sat_2018_total','act_2017_composite','act_2018_composite'])
# Out:
# /home/jane/anaconda3/envs/my_env/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# There's a negative correlation between participation rate and average scores. As we expected, the lowest participating states tend to send primarily their best students and have the highest scores.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ![map of participation rate for 2017 SAT](../data/sat_2017_par.png)
# Map of participation rate for 2017 SAT
# ![map of participation rate for 2018 SAT](../data/sat_2018_par.png)
# Map of participation rate for 2018 SAT
# ![map of participation rate for 2017 ACT](../data/act_2017_par.png)
# Map of participation rate for 2017 ACT
# ![map of participation rate for 2018 ACT](../data/act_2018_par.png)
# Map of participation rate for 2018 ACT

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
def subplot_distplot(dataframe, list_of_columns, list_of_titles):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough row
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15,5*nrows)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    if len(list_of_columns) %2 !=0:
        ax[len(list_of_columns)].set_visible(False)
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        sns.distplot(dataframe[column],bins=10,color="#3F5D7D",ax=ax[i]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].set_title(f' Count of States by\n {list_of_titles[i]}', fontsize =18)
        ax[i].set_ylabel('Count of States',fontsize=15)
        ax[i].set_xlabel(list_of_titles[i],fontsize=15);
        ax[i].spines["top"].set_visible(False)  
        ax[i].spines["right"].set_visible(False)
        ax[i].axvline(dataframe[column].mean(), color='r',linewidth=1,linestyle='dashed',label='Mean')
        ax[i].axvline(dataframe[column].median(), color='g',linewidth=1,linestyle='dashed',label='Median')
        ax[i].axvline(dataframe[column].mode()[0], color='b',linewidth=1,linestyle='dashed',label='Mode')
        ax[i].legend()
    plt.tight_layout()

# %%
subplot_distplot(final,final.columns,final.columns)

# %%
final.describe().loc[['std','mean']]
# Out:
#       act_2017_par  act_2017_eng  act_2017_math  act_2017_reading  \
# std      32.140842      2.353677       1.981989          2.067271
# mean     65.254902     20.931373      21.182353         22.013725
#
#       act_2017_science  act_2017_composite  sat_2017_par  sat_2017_ebrw  \
# std           1.739353            2.020695     35.276632      45.666901
# mean         21.450980           21.519608     39.803922     569.117647
#
#       sat_2017_math  sat_2017_total  act_2018_par  act_2018_composite  \
# std       47.121395       92.494812     34.078122            2.117686
# mean     556.882353     1126.098039     61.627451           21.498039
#
#       sat_2018_par  sat_2018_ebrw  sat_2018_math  sat_2018_total
# std      37.314256      47.502627      47.772623       94.155083
# mean     45.745098     563.686275     556.235294     1120.019608

# %% [markdown]
# Answers: In this dataset, the distribution of SAT & ACT participation rates and average scores are non-normal and  show bimodal distribution which is a distribution with two different modes. The mean, median, mode values are not equal. Standard deviation tend to much lower than mean value, which indicate that the data is spread out over a small range of value except participation rates.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No, the sample are not normally distributed based on the observation above.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: The assumptions hold for Math, Reading and Rates.Fundermental assumption for parametric calculations in statistics is that the underlying populations is normally distributed. Parametric calcualtions(e.g., confidence interval) can be incorrect(wrong mean and standard deviation) when the data are non-normally distributed.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: Inference statistics are calculated with the purpose of generating findings from samples to entire population of interests which is relying on appropriate sampling method. The SAT and ACT participation rate are caculated based on entire poplution of high school graduates who participate the test, it is hard to define the sampling and population size. In addition, parametric statistics are most common approach to describe inference statistics, as mentioned above, parametric statistics rely on an assumption that the given variable are normally distributed.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: SAT and ACT tests are different test, it is not appropriate to compare the subset scores which are not even in the same range and scale. In addition, higher average Math score doesn't indicate that overall students pefomed better because of different participation rate. There's a obvious negetive correlationship between participation rate and scores.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Answer:
#
# Though the SAT continues to reign in popularity on the East and West coasts, the ACT is the more popular test in the Midwest for many years. However, based on [Colorado Department of Education](https://www.cde.state.co.us/assessment/coloradosat) and [Illinois State Board of Education](https://www.isbe.net/Documents/Letter-High-School-Growth-20180618.pdf), the selection committee chose the SAT for the 11th grade college entrance exam of the states of Colorado and Illinois from 2018. The ACT had provided state-paid testing for 11th-graders until 2015, the College Board won a bid to administer its SAT college entrance exam to public school juniors. This result in a large increase in Participation rate on SAT and decrease on ACT in these two states.
#
# The District of Columbia's participation rate for SAT has decreased from 100% to 92% while the state's participation rate on ACT test didn't change at all. SAT is not a mandatory test in the state, but the SAT is offered for free to all juniors and seniors in Washington, DC. The possible reason for the decreasing in participation rate might be that more colleges and universities in the D.C. metro area are becoming test optional, students no longer need to submit test scores to enter colleges and universities.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# **Key findings:**
#
# From the data, it's reasonable to conclude that statewide testing causes lower scores because it includes all seniors and not just those planning to apply to college.
#
# Though the SAT remains popularity on the East and West coasts, the ACT is the more popular test in the Midwest in 2017. But this year, 2 million U.S. students from the class of 2018 took the SAT, compared with 1.9 million who took the ACT. About 1.7 million students took the SAT last year.The The SAT is gaining momentum in recent years [Source: Politico.com](https://www.politico.com/newsletters/morning-education/2018/10/25/sat-scores-rise-as-do-the-numbers-of-test-takers-388387). The College Board has won key battles in the statewide-contract war. New contracts with Colorado and Illinois, College Board data show, were instrumental in the SAT’s growth. Some states require all juniors to take the SAT(Connecticut, Delaware, Maine, Michigan, and New Hampshire), while others, such as Idaho, Michigan, Illinois, Colorado, and New Hampshire have statewide contracts that cover the cost for students, and give students the option of taking either the SAT or ACT. Because the test wasn't mandatory for all students in these states for the entire school year, participation rates here are below 100%.
#
# College Board pushed to expand its market share in recent years by revising the test(released in 2016, making it far more appealing as an assessment test than the older version of the test) and entering into deals with numerous states and school systems to give students the exam. In 2010, the College Board introduced a SAT School Day that offering free SAT exam during a regular school day with the cost covered by their schools, not their parents. In addition, students who choose to participate in SAT will be connected to resources and activities designed (e.g., Khan Academy) to help identify next steps for extra support or possible acceleration.
#
# **Recommendations:**
#
# There are a number of other states where some schools or districts can administer the SAT to their students (either as an option or a requirement). These states are mainly located in Midwest and South where the ACT is dominated.
# Direct method: Collaborate with state departments of education and local education agencies set up a statewide testing requirements, full or partial funding or free test preparation programs.
# Indirect method: Covering all or part of exam fees, Offer more SAT school Days, collect more data from school district to help find more suitable target.
